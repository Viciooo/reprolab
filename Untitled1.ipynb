# %%
# !pip install poetry
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 26.7 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#   Attempting uninstall: virtualenv
#     Found existing installation: virtualenv 20.25.1
#     Uninstalling virtualenv-20.25.1:
#       Successfully uninstalled virtualenv-20.25.1
#   Attempting uninstall: poetry-core
#     Found existing installation: poetry-core 1.9.0
#     Uninstalling poetry-core-1.9.0:
#       Successfully uninstalled poetry-core-1.9.0
#   Attempting uninstall: pkginfo8;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [poetry-core]
#     Found existing installation: pkginfo 1.10.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [poetry-core]
#     Uninstalling pkginfo-1.10.0:49;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [poetry-core]
#       Successfully uninstalled pkginfo-1.10.00m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/11 [poetry-core]
#   Attempting uninstall: build╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/11 [pkginfo]y-core]
# ...

# %%
# !pip install dvc
